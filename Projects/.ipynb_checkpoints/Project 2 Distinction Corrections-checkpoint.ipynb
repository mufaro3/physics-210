# %% [markdown]
# Dear Joss,
#
# Thanks for the feedback. I'll describe the changes I've made to each of your comments, and I hope these changes are sufficient.

# %% [markdown]
# ## The Big Things

# %% [markdown]
# > Another great project Mufaro. Some of similar issues related to communication are showing up here as in your first project. There are sections where you present large numbers of sequential figures, but don't do a great job of orienting the reader to what you are doing (what's different in the parameters from one fig to the next), but even more importantly WHY you are doing it. I will use your edge-case explorations as an example.
#
# This sounds like a great idea.
#
# > As an example, for Section 5 (phase space exploration), you should start with a brief paragraph discussing what you are actually going to be doing in this section, including why only up to 1E-13 radians and 10 electrons. You should then add less-detailed interpretations in terms of what is observed. As we see in Fig 8, radius variance tends to increase with number of electrons, but there are some interesting behaviours for n=4 and 6 where we see some strong angular dependence that isn't seen for other numbers of electrons.
#
# I've gone through and taken the time to make some of these changes. I'm going to assume that the sections you are most referring to are direct case tests, like the example visual test in section 4.1 and all of the phase space edge cases in section 6. Therefore, I added the following descriptions:
#
# - (4.1) Now, we can perform a visual test of $n=5$ with an incidence angle of $\theta=-10^{-14}$ rad. It's a very small incidence angle, so this should be a roughly stable orbit, for some period of time before eventually breaking orbit. The purpose of this experiment is to visually see the mechanics of this system in action, and in doing so, we can see how the system's stability evolves with time.
# - (6.1) In this test case, we'll be exploring the edge of the "sea of stability" using 3 electrons and a perturbation angle of $10^{-13}$ radians. The purpose of this exploration is to try and visually demonstrate how the periodicity of these models evolves over time to become unstable.
# - (6.2) In this test case, we'll explore the "Goldilocks Zone" (a local minima of instability on the contour) located at 7 electrons with a perturbation angle of $\theta=10^{-13}$. The purpose of this exploration is similar as before, to witness the time evolution of the periodicity of this simulation to see where and when it becomes unperiodic.
# - (6.3) In this test case, we'll explore the peak of instability (a local maxima) located at the brightest yellow local fringe at $n=6$, $\theta=-10^{-13}$ radians on the contour. The purpose of this simulation is much like the previous two: to see the time-evolution of the periodicity of this simulation to determine how it becomes unperiodic over time.

# %% [markdown]
# ## The Little-r things

# %% [markdown]
# Now, here are the rest of the smaller comments, each in order:

# %% [markdown]
# > You will want to decide if the main reader-facing document should be html or PDF. With your current formatting, latex isn't working in your markdown for html BUT your PDF has two sets of section numbers for each section.
#
# This is a good point. I think this is just an issue with my local Jupyter installation. I don't have a single clue why I'm getting such a headache rendering TeX. I think, given my case, PDF probably makes the most sense as the decision comes down to having double section numbers vs. all of my equations being unreadable. To resolve section numbering, I'll just remove the section numbers from the Jupyter document itself and have it become autogenerated by the LaTeX engine.

# %% [markdown]
# > Your first sentence of your introduction is confusing because you refer to only one electron and one nucleus, but call it an n-body system.
#
# The sentence in question is "The purpose of this project is to explore the orbital stability as a function of minor angular interference on a singular electron in $n$-body systems with a fixed nucleus." I think the confusion in this sentence is that I state that there is interference on a singular electron, and there is only a single nucleus for each simulation. It's very easy to think that it refers to the entire system consisting of a single electron and the one nucleus. What I mean't to convey is that there is only one electron being affected (but more than one electron in the system), and there is only one nucleus, but this nucleus is comprised of dynamically increasing protons (but the nucleus acts as one rigid object, so it is effectively just one particle increasing in charge).
#
# To rectify this, I'm changing this sentence to "The purpose of this project is to explore the orbital stability for a neutral-charge systems of many electrons and one nucleus as a function of very slight perturbations to the angular direction on a single electron in the system."

# %% [markdown]
# > I feel that there is some ambiguity in your angular period definition since if you are perturbing only one of the electrons, it is possible that not all electrons maintain a common angular period.
#
# This is true, and I'll clarify that this is all with respect to the incidence electron, so the sentence
#
# "...orbital distance of all electrons in the system over an angular period (that being, in the time that it takes the electron to reach the same angle with respect to the nucleus, how much does the distance that electron travels deviate on average)."
#
# is changed to
#
# "...orbital distance of all electrons in the system over an angular period of the incidence electron (that being, in the time that it takes the perturbed electron to reach the same angle with respect to the nucleus, how much does the radial displacement from the nucleus deviate, on average, for each electron in the system)."

# %% [markdown]
# > I struggled to understand the point you were trying to make in the second assumption, related to why, for example, n=3 and n=4 should be the same stability.
#
# The statement "$n=3$ and $n=4$ should also be roughly the same stability" was just completely wrong. What I meant to say is that they are of *similar* stability, or even more precisely, that they are more similar in stability compared to $n=1$ and $n=2$ or $n=5$ and $n=6$. This is because the Bohr model predicts orbitals that are filled in pairs, so the model should start to become very unstable at $n=3$, adding an additional electron should still increase the instability but not as dramatically as the transition to $n=5$ electrons (as this would fill a new orbital/energy level). This assumption also is meant strictly for running an orbital simulation without any angular perturbation.
#
# To rectify this, I've altered the statement
#
# "we can theoretically predict that simulations of $n=1$ or $n=2$ should be roughly the same stability, $n=3$ and $n=4$ should also be roughly the same stability, and then for each **even** $n$ roughly greater than 4, the orbits should begin to become generally unstable due to deviating more and more from Bohr's model at higher $n$."
#
# to
#
# "we can theoretically predict that without providing any angular perturbation whatsoever, simulations that occur at ground-state energy levels ($n=1$ and $n=2$) should remain stable, then simulations at the immediate next energy level should be of similar stability levels ($n=3,4$), and then configurations at higher energy levels should become increasingly more unstable due to all electrons existing at the same energy."

# %% [markdown]
# > Please add in your validation section two use-case examples for smooth and show the data before and after smooth is applied for one where the smoothing is fully applied and a case where the data should not be smooth. As a reader I need convincing that it is NOT smoothing data that I think should be treated as having variance.

# %% [markdown]
# I think the smartest thing to do in this scenario, actually, is to remove the smoothing function altogether. The mentality behind its inclusion was to aid in visuals, such as in convincing the reader that the plot of radial displacement for the trivial case
#
# ![image.png](attachment:image.png)
#
# is actually a (near) completely constant plot at $a_0$. It seemed inherently confusing to display graphs that were clearly not flat/linear then state that this is proof that these is a perfectly circular orbit (as perfect as this algorithm can allow), so a smoothing function was introduced to try and rectify this, but like you state later, it is probably better to directly show this variance, prove to the reader that this is circular based on examining the scale of this plot, and then remove all smoothing altogether when plotting. Most importantly, I had undoubtedly failed to clarify that smoothing was not used for any variance calculations, only for plotting, so it was intended as a visual aid. It didn't even work when included in the trivial case, hahaha.

# %% [markdown]
# > Your `cartesian_to_polar` test and other similar tests should all be in validation, not the main body. This will provide significant improvement on the overall readability of these early sections. The above being said, things like the mini-test of the simple case are great to include in the main body

# %% [markdown]
# Your wish is my command. It is done. Took me a lot of clicking.

# %% [markdown]
# > Fig 2 and Fig 3: I believe you are mischaracterizing the issues as floating point errors. These small variations are much more likely to be consequences of the actual algorithm and the fact that things are being evaluated at discrete times.

# %% [markdown]
# You're probably right. There is probably some aspect of it that is floating point error, but Python's minimum precision limit is big enough to handle these numbers reasonably. I'll rectify this by changing the caption under figure 2 from
#
# "The radial trajectory also confirms our claim. The variance of the graph can best be explained by floating point precision errors, as the variance of the graph is actually extremely small in comparison to $a_0$ (about $-2$ to $3\times 10^{-19}$ against $5.3 \times 10^{-11}$), so all of these values can be said to be roughly $a_0$."
#
# to
#
# "The radial trajectory also confirms our claim. The variance of the graph is extremely small in comparison to $a_0$ (about $-2$ to $3\times 10^{-19}$ against $5.3 \times 10^{-11}$), so all of these values can be said to be roughly $a_0$. The minor variance seen is so small that it is likely the result of the discrete time evolution of this simulation."
#
# And similarly, figure 3 can be altered from
#
# "Furthermore, the speed vs. time graph further confirms our suspicions. We see a variation in the graph here as well due to floating-point errors, even in the trivial case, as this speed should be constant. Otherwise, however, as each of these values are roughly near each other, we can further state that the differential equations used are correct up to the point of floating point error."
#
# to
#
# "Furthermore, the speed vs. time graph further confirms our suspicions. We see another near-zero variation relative to $a_0$ in the graph here as well, even in the trivial case, as this speed should be constant. Otherwise, however, as each of these values are roughly near each other, we can further state that the differential equations used are correct up to the fundamental limitations of using discrete time evolution."

# %% [markdown]
# > All of your trajectory plots should use 1:1 aspect ratios so that circles appear as circles.

# %% [markdown]
# This is a good idea, and a simple fix: `figsize=(6,6)`.

# %% [markdown]
# > Figure 4: You refer to this as a mostly stable system, but your introductory descriptions of stability with uniform circular orbits do not match what is shown in this figure.
#
# I see what you mean. I'm at a bit of a loss for how to perfectly clear up my wording here, but I think the point I'm trying to get across is that perfectly-stable systems are defined as circular, and the more circular the orbital systems are, the more stable they are. In this case, calling the system stable is both unintuitive and wrong. I don't think it makes sense to say "stable" and "unstable," rather, it's better to refer to the periodicity of the orbit. In this case, the orbital pattern
#
# ![image.png](attachment:image.png)
#
# is periodic but (obviously) becomes an unstable orbit eventually (again, this is why it is unintuitive to call it "stable" or "unstable," as any non-perfectly-stable orbits will eventually completely destabilize). So I'll use the term "periodic" instead. This means that this caption will be altered from
#
# "For a 5-electron, mostly-stable system, we get a plot of the electrons motion that is distinctly reminiscent of the Rutherfordian nuclear model, which is a natural extension of the Saturnian model."
#
# to
#
# "For a 5-electron system, we get a plot of the electrons motion that is distinctly reminiscent of the Rutherfordian nuclear model, which is a natural extension of the Saturnian model. As can be seen, the first period of orbit is completely periodic, with all electrons beginning and ending in the same place."

# %% [markdown]
# > We need more clarity on what is different from Fig 4 to 5 and if there were any asymmetries introduced into the system. Approximately how many orbits are represented in fig 5 (were things stable for a while and then decayed or did things go poorly for the system almost immediately after the first orbits?)

# %% [markdown]
# Right. Figure 4 is intended to display the full periodic nature of the initial orbits in the system, and figure 5 is intended to display how this periodicity is broken (and how, once the periodicity is broken, the system doesn't return to stability). To clarify this, I've changed the caption of figure 5 from
#
# "Alternatively, this is the full cartesian trajectory for all of the electrons during the simulation. Some of the electrons fall into the nucleus and some are ejected. The main takeaway is that once a singular electron in the system is unstable, the orbital system of all of the electrons becomes unstable."
#
# to
#
# "Alternatively, this is the full cartesian trajectory for all of the electrons during the simulation. Some of the electrons fall into the nucleus and some are ejected. The main takeaway is that once a singular electron in the system is unstable, the orbital system of all of the electrons becomes unstable. Whereas figure 4 displayed the initially periodic behavior of the simulation, it can be seen here that in the long term, this periodicity can be completely broken (i.e., the system destabilizes)."

# %% [markdown]
# > Figure 6 needs more context. Where does the electron start? What is the incidence angle?
#
# Again, this is modelling the same previous scenario, just with a particular focus on the singular electron that was rotated to begin the simulation. I must have failed to clarify that for every simulation, the perturbed electron is always the electron that begins at $\theta=0$ (or $(a_0, 0)$ in cartesian coordinates), and the incidence angle is the angle that was described at the beginning of the simulation, $\theta = -10^{-14}$ rad. I'll rectify this by changing the caption
#
# "The incidence angle produced a non-uniform orbit, being greatly ovular without the nucleus as the center. We can be certain that the orbit path is still stable for some time, but after a certain point, the incidence electron diverges from the stable path and flies outward."
#
# to
#
# "Further examining the trajectory of the perturbed electron ("Electron 1" in figure 5, perturbed with a rightward rotation by $10^{-14}$ rad) shows that perturbation produced a non-uniform orbit, being greatly ovular without the nucleus as the center. Thus, we can be certain that the orbit path is still stable for some time, but after a certain point, the incidence electron diverges from the stable path and flies outward."
#
# Because of how important noting that all perturbed electrons start from the same place in all simulations regardless of $n$, I've added that to the top of the document:
#
# "To do this, for every number of electrons $n$, I'll equally radially space the electrons around the nucleus (which will have a charge and mass equal to $n$ protons such that the overall atom is completely neutral), and for every simulation, perturbation will only occur on the singular electron placed at the angle $\theta=0$ to the nucleus (or $(a_0,0)$ in cartesian coordinates)."

# %% [markdown]
# > Fig 7: Why is it expected that the electron will maintain a stable orbit for about 3 periods.
#
# First, I think that it was just a communication error in writing
#
# "As expected, the electron maintains a stable orbit for about three periods before diverting off path"
#
# as I did not predict the exact number of periods at which the system would remain stable (and, again, the use of "stable" vs. "unstable" is unintuitive for reasons mentioned previously). Rather, I predicted that the system should have a periodic orbit for some duration of time and then this periodicity would break. Therefore, I'll change the sentence to
#
# "Once more, the electron maintains periodic behavior in orbit, energy, and speed for a duration of time before destabilizing and becoming unperiodic in all three aspects."
#
# I'd also like to add that the statement
#
# "so the system was certainly destabilized by having a higher $n$ and $\theta$, but having $\theta$ be so low still kept the orbit stable for quite a while before a complete destabilization."
#
# isn't actually proven at this point in the study (but is proven later with the contour), so it's not really necessary to include here (again, because I had not predicted the number of stable periods/duration of periodicity). I'll remove this statement.
#
# > And this figure is also missing a lot of context. How many electrons?
#
# Furthermore, yet again, this graph is liked to the same system of 5 electrons with an incidence angle of $\theta=-10^{-14}$ rad. I thought that it would be implicit that all of these graphs cover the same simulation, but I'll restate this information to increase readability with
#
# "Once more, for a simulation of 5 electrons and given a perturbation of $\theta = -10^{-14}$ radians,"
#
# > Also you describe the speed graph as sinusoidal, which it isn't
#
# I can safely remove
#
# "Similarly, the speed graph is seemingly perfectly sinusoidal for roughly the first three periods then deviates from this path on the fourth."
#
# as the previous alteration mentions this periodicity in the speed graph.
#
#
# Therefore, the full caption changes from
#
# "As expected, the electron maintains a stable orbit for about three periods before diverting off path, so the system was certainly destabilized by having a higher $n$ and $\theta$, but having $\theta$ be so low still kept the orbit stable for quite a while before a complete destabilization. Similarly, the speed graph is seemingly perfectly sinusoidal for roughly the first three periods then deviates from this path on the fourth. Furthermore, we can further verify the correctness of this simulation as the total mechanical energy stays constant. We can also notice how the periodic trend of total kinetic and potential energy across the simulation is maintained up to the orbit breakage point, but even when this point is reached, the total mechanical energy in the system is still kept conserved even despite the orbit breaking, which further validates the simulation's mechanics."
#
# to
#
# "Once more, for a simulation of 5 electrons and given a perturbation of $\theta = -10^{-14}$ radians, the electron maintains periodic behavior in orbit, energy, and speed for a duration of time before destabilizing and becoming unperiodic in all three aspects. Furthermore, we can further verify the correctness of this simulation as the total mechanical energy stays constant. We can also notice how the periodic trend of total kinetic and potential energy across the simulation is maintained up to the orbit breakage point, but even when this point is reached, the total mechanical energy in the system is still kept conserved even despite the orbit breaking, which further validates the simulation's mechanics."

# %% [markdown]
# > Fig 8: Given that this is symmetric, you probably only need to demonstrate a more minor version of this symmetry in the appendix and then use only positive perturbation angles here, referencing that you have demonstrated elsewhere it is symmetric.

# %% [markdown]
# I actually made a mistake to call this symmetric, so I disagree with this notion. This graph is not actually symmetric. Rather, it's more mostly-symmetric, and that is because of the physical interpretation of the turning directions. An electron performing a negative turn is going rightward and leaving the atom whereas the electron with a positive turn is turning leftwrad into the atom, so the difference between repulsion and attraction energies across the two cases are probably not the same due to the differences in distances. This is only really notable at $n=6$, but it's important to keep in mind that this graph isn't entirely symmetric. To do this, I'll just directly add the following description to the caption of figure 8:
#
# "Furthermore, this graph is mostly-symmetric, and that is because of the physical interpretation of the turning directions. An electron performing a negative turn is going rightward and leaving the atom whereas the electron with a positive turn is turning leftwrad into the atom, so the difference between repulsion and attraction energies across the two cases are probably not the same due to the differences in distances. This effect is most notable at $n=6$ electrons."

# %% [markdown]
# > The case studies you look at after figure 8 would be better set up if you had annotations.

# %% [markdown]
# I'm not quite sure what you mean by this. I could surely annotate these graphs, but I'm both not sure what annotations would be necessary and what an annotation would add that the captions don't already convey. For the time-based plots, the most important aspect is just that they have periodic behavior then suddenly become unperiodic, and for the trajectory plots, the important aspect is seeing the shape and size of the orbital trajectory, and I feel as though this is examined in detail in the captions. Thanks!

# %% [markdown]
# > > "general trend of greater instability at higher 𝑛, and two regions of  instability at high $\theta$ and roughly $n=4$ and $n=6$, and this is due (most likely) to the orbital geometry at these counts (square and hexagon) being more sensitive to stronger perturbation angles as opposed to more radially spread-out geometries combined with the deviation from the Bohr model predicted in the introduction at these even integer values"
# >
# > I'm struggling to follow this argument. Why would these specific geometries be more sensitive as compared to $n = 8$ or 10, for example?

# %% [markdown]
# This is because beyond $n=6$, the instability of the system increases without respect to the turning angle due to the aforementioned lack of spacing based on Bohr's Model (i.e. a lack of orbitals), so we can only see geometric effects at low $n$ as higher geometries are just trivially unstable regardless of their configuration.

# %% [markdown]
# > Fig 9, 11 and 13. These might benefit from being multi-panel plots where you show in a second plot the behaviours of all of the electrons, like you did with Fig 5

# %% [markdown]
# Your wish is my command. And so it is done. However, I've opted to not place the plots of the singular electron and all of the electrons onto a singular multi-panel plot because the incidence electron plot is actually contained on the plot of all of the electrons anyway, so it's important to emphasize that the plot of the incidence electron is being examined in close detail without respect to the full system.

# %% [markdown]
# > Fig 12: you describe a lot of behaviours as expected, but do not indicate why these behaviours were expected.
#
# Right. I'll fix this by altering the caption from
#
# "The total energy of the system is negative and conserved, which is predicted behavior, and the total kinetic energy of the system increases as the electron accelerates towards the nucleus (alongside a matching decrease in potential energy), a behavior which is also expected."
#
# to
#
# "The total energy of the system is negative and conserved, which is predicted behavior because the net repulsive energy between the electrons is greater than the kinetic energy of the electrons. Additionally, the total kinetic energy of the system increases as the electron accelerates towards the nucleus (alongside a matching decrease in potential energy), a behavior which is also expected because as the system's orbit destabilizes, all of the electrons in the system begin to rapidly get either ejected from the atom or sucked into the nucleus, and in both scenarios, the electrons speed up quickly."

# %% [markdown]
# > Fig 15: what are the initial conditions for this one?

# %% [markdown]
# For each test case, the initial conditions are written at the beginning of the section, so this test case has 6 electrons and a perturbation angle of $-10^{-13}$ radians. To clarify this, I'll write this out at the top of each test case just to be absolutely clear.

# %% [markdown]
# > Conclusions feedback:
# > - Point 1: This is strictly due to the differences in a quantum vs classical system.
#
# I think this is less due to quantum vs. classical predictions and more due to the model. Even in the gravitational case, such as with our solar system, multiple objects have to orbit at varying distances to maintain a stable orbit. The difference, of course, is that these energies are repulsive potentials rather than attractive potentials. Bohr's model, most importantly, includes a component for varying the radial distance, and a classical system would also need the distances to vary as the number of objects are increased, so the quantum vs. classical difference is really that Bohr's model predicts that that the acceptable radii for orbit are quantized rather than being continuous (however, again, I didn't really explore this difference, so I don't think I need to make any change to my current description).
#
# > - Point 2: You have not demonstrated that radially nonsymmetric arrangements do not produce stable orbits.
#
# You are right. I'll change the description from "Radially symmetric arragements of the electrons aid in producing stable orbits, but certain orbital geometries.." to "Certain radially symmetric orbital geometries..."
#
# > - Point 3: I feel like I'm still missing a piece here. Maybe your introduction needs to show, ideally with annotated figures but perhaps just with tabular information, how your various parameters change based on $n$.
#
# I think that this point was just really poorly written, to be honest. I wrote
#
# "At higher $n$, particularly about $n=7$, the ratio between the size of the incidence angle and the size of the system becomes so small that the system effectively begins to increase in instability without regard to the perturbation."
#
# But really, the point should be far more general than that, that the systems start to become so cluttered with Electrons with no change to the radial distance, so the repulsion energy becomes high enough that the systems become increasingly unstable without respect to the perturbation angle under the angular domain explored. The only necessary evidence for this should be figure 8, simply looking at how at $n=7$, the graph becomes uniform vertically. To rectify this, I'll change it to
#
# "Once the system reaches $n=7$ electrons, the system can be said to be cluttered or overly-dense with electrons. At this point, the repulsion energy between the electrons is so high that the system will quickly become unperiodic, and increasing $n$ from this point makes the systems increase in instability without respect to the angle of perturbation, and this is proven by how figure 8 is vertically uniform at $n=7$ and beyond."

# %% [markdown]
# > Section 7.3 formatting for your enumerated list does not appear to be working correctly.

# %% [markdown]
# It works on the Jupyter Notebook, so I'll just have to try remaking the PDF and see how that works.

# %% [markdown]
# Thanks, Joss. I hope these corrections are good. Let me know about anything new.
#
# Regards,
#
# Mufaro Machaya
