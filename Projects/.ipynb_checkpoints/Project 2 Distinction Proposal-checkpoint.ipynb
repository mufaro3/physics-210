# %% [markdown]
# # Project 2 Distinction Proposal

# %% [markdown]
# I'm intending to reach distinction level 2 with this project.

# %% [markdown]
# ## Physics and Physical Modelling

# %% [markdown]
# My physical question is somewhat simple, but given this simple situation, the mechanics are modelled as best as it possibly could be. The physical question of utilizing degenerate electrons and radial symmetry allows for the model to be completely in-line with literature expectations, and this is proven in the validation section, so the physical modelling of this system is completely correct.

# %% [markdown]
# ## Coding

# %% [markdown]
# I'm very proud of my present programming practice on this project. I was sure to be even more rigorous and disciplined with the program structure as compared to last project, as the program is not only split into functions, but moreso, each function is coupled with a series of tests designed to ensure that everything is working purely as intended.

# %% [markdown]
# ## Communication of investigation

# %% [markdown]
# I felt as though my communication was quite successful, as I made good use of mixing in LaTeX derivations to match code alongside extensive use of markdown cells, docstrings at the top of functions, and inline comments all to explain each step of the investigation. The notebook is written directly in-order for ease of reading, and each explanation is simplified as much as possible.

# %% [markdown]
# ## Quality of investigation

# %% [markdown]
# I feel as though this is where my project shines the best. I had a simple project idea, but I went quite far into understanding the full mechanics of the simulation through exploring a variety of cases of the simulation, and I was particularly proud of how quickly these considerations allowed me to generate further questions stated in the "Future Work" section.
