# %% [markdown]
# # Project 1 Distinction Corrections

# %% [markdown]
# Dear Joss,
#
# Thank you for your requests for corrections. I've made the following alterations, and I hope that they meet your requests.

# %% [markdown]
# > Hi Mufaro. I love your project. As you will see below, almost all the comments are related to increasing the quality of the communication in the project as the project itself is already very ambitious. These points are simply my points of feedback as I read linearly through your project.
#
# Wonderful. I'll discuss each part of your feedback, line by line:

# %% [markdown]
# > Your latex embedded in the markdown is not rendering
#
# Again, this is the standard problem from before. I've just given up trying to get my Jupyter HTML exports to render the LaTeX on other devices entirely, so I'll produce a PDF for the final output and make sure that it's nice and readable.

# %% [markdown]
# > Fig 1 caption is confusing. Are all three objects colliding simultaneously? What is meant by "black hole at a stellar radius"
#
# A must have gotten confused when writing this caption. The black hole is at a stellar mass (i.e., it's a [stellar black hole](https://en.wikipedia.org/wiki/Stellar_black_hole)), but the radius isn't necessarily 'stellar' (I described it as being intentionally based off of the radius of Mercury from the Sun). I'll fix this by changing it from
#
# "A basic rendition of the $3$-body system encompassed by this project. The general idea of this project is the collision between the space ship, the slime planet, and the black hole at a stellar radius."
#
# to
#
# "A basic rendition of the $3$-body system encompassed by this project. The general idea of this project is modelling the possible collisions between the space ship and slime planet given the presence of a gravitational field due to a fixed black hole."

# %% [markdown]
# > "The ship will need to perform a turn of angle $\theta$ to have a proper head-on collision."
# >
# > Worth making sure this is captured in your earlier context...why is the ship trying to have a proper head-on collision?

# %% [markdown]
# I think the misconception, first and foremost, is that the ship isn't necessarily trying to make a head-on collision in particular. The point is that, without turning, the planet would not collide with the ship, but this would result in the ship being sucked into the black hole. If the ship makes a full turn to completely avoid collision, then it would probably run out of fuel quickly. If the ship manages to collide with the planet to bounce off without being broken, it could maximize the distance it travels from the black hole and minimize the fuel it expends.
#
# To try and make this more clear, I'll change
#
# "The ship will need to perform a turn of angle $\theta$ to have a proper head-on collision. This will require the ship to apply thrust to perform the turn, but this turn will require a certain amount of energy. Let's assume that the ship starts with a certain amount of fuel on board (but it will require fuel to accelerate/deccelerate during its journey)."
#
# to
#
# "As the ship is on a course for being sucked into the black hole, it would be best for the crew members to turn the ship out of the direction of the black hole. This turn may cause it to turn into the slime planet or completely away from the black hole. In either case, this will require the ship to apply some thrust to perform the turn, and this thrust will require a certain amount of energy. Let's assume that the ship starts with a certain amount of fuel on board (but it will require fuel to accelerate/deccelerate during its journey)."

# %% [markdown]
# > "The ship is designated as "sufficiently turned" once the direction of the velocity $\hat{v}$ is equal to the direction of thrust $\hat{T}$, given that the direction of thrust is equal to the rotation of the direction of the initial velocity vector $v_0$ by $\theta$, with the equation"
# >
# > I am unable to parse what is meant by this sentence.

# %% [markdown]
# What I mean is that all turning stops once the ship is oriented in the direction it wants to reach resulting from the turn. For example, say the ship starts with an angle $\theta$, and we want to turn by $\Delta \theta$. All turning will stop once the ship reaches $\theta + \Delta \theta$, and the ship will retain all of the fuel it has from that point onward. No turning will continue afterward either if the ship happens to naturally turn due to gravity.
#
# To make this clear, I'll change
#
# "The ship is designated as "sufficiently turned" once the direction of the velocity $\hat{v}$ is equal to the direction of thrust $\hat{T}$, given that the direction of thrust is equal to the rotation of the direction of the initial velocity vector $v_0$ by $\theta$, with the equation"
#
# to
#
# "The ship will stop turning once the ship is in the direction the turn intended to produce, i.e., if the ship begins with a direction $\theta$ and it seeks to turn by $\Delta \theta$, all turning will stop once the ship reaches $\theta + \Delta \theta$, and the ship will not resume turning even if it naturally turns off of $\theta + \Delta \theta$ afterward (due to gravity or otherwise). This is determined by checking if the directio nof velocity is equal to the direction of thrust $\hat{T}$:"

# %% [markdown]
# > Additional physics: Ensure EVERY variable introduced in this section is defined, as well as any terminology introduced

# %% [markdown]
# I used/defined the following variables:
#
# Gravitational Equation:
#
# 1. $\mathbf{F}_g$ - The force of gravity (not explicitly defined)
# 2. $G$ - Gravitational Constant (not explicitly defined)
# 3. $m_1$, $m_2$ - Masses (for the gravity equation) (not explicitly defined)
# 4. $\mathbf{r}$, $\hat{r}$ - Displacement and Direction (for the gravity equation) (not explicitly defined)
# 5. $\mathbf{x}$ - Position (not explicitly defined)
#
# Newton's Second Law
#
# 6. $\mathbf{F}$ - Net Force (not explicitly defined)
# 7. $\mathbf{x}$ - Position (not explicitly defined)
# 8. $m$ - Mass (not explicitly defined)
# 9. $t$ - Time (not explicitly defined)
#
# Thrust:
#
# 10. $\hat{T}$ - Direction of Thrust
# 11. $\mathbf{R}(\theta)$ Counterclockwise Rotation Matrix by $\theta$ (not explicitly defined)
# 12. $\hat{v}_0$ - The initial direction of the space ship (not explicitly defined)
#
# Hunt-Crossley Model:
#
# 13. $F_N$ - Normal Force (not explicitly defined)
# 14. $k$ - Stiffness Constant (not explicitly defined)
# 15. $\delta$ - Overlap Distance (not explicitly defined)
# 16. $n$ - Nonlinear geometric constant (not explicitly defined)
# 17. $\alpha$ - Damping Constant (not explicitly defined)
#
# I think the problem is that I assumed far too much about what was obvious to the reader here. I think that Newton's second law is somewhat trivial, and I was definitely more explicit with the thrust equation, but I very weakly introduce the Hunt-Crossley Model (and then I don't really explain it in any depth later, which is a problem I'll discuss in a further point you've made) and just assume the reader is familiar with the gravitational equation. I'll just be extremely explicit regarding these variables (and go into a lot more depth on the more involved equations).
#
# For example, the gravitional equation can be changed from
#
# > 1. $n$-Body System, Gravitational Vector Field
# >
# > Each of the three objects are modeled individually as point-masses. Each object produces gravitational effects on all other objects by formula
# >
# > $${\bf F}_g = G \frac{m_1 m_2}{|{\bf r}|^2} \hat{r}.$$
# >
# > From there, basic kinematic equations apply:
# >
# > $$\frac{d^2 \bf{x}}{dt^2} = \frac{\sum \bf F}{m}.$$
# >
# > The system is modeled in only two dimensions rather than three (but all equations apply for each dimension)
#
# to
#
# "1. 3-Body System, Gravitational Vector Field
#
# Each of the three objects are modeled individually as point-masses. Each object produces gravitational effects on all other objects by formula
#
# $${\bf F}_g = G \frac{m_1 m_2}{|{\bf r}|^2} \hat{r}$$
#
# where ${\bf F}_g$ is the force of gravity, $G = 6.67 \times 10^{-11}$ $m^3 kg^{-1} s^{-2}$ is the gravitational constant, $m_1$ and $m_2$ are the masses of the objects, and ${\bf r}$ is the displacement vector between them. From there, basic kinematic equation of Newton's second law applies:
#
# $$\frac{d^2 \bf{x}}{dt^2} = \frac{\sum \bf F}{m},$$
#
# where $\frac{d^2 \bf{x}}{dt^2}$ is the acceleration for the object of mass $m$ given the calculated net-force ${\sum \bf F}$. The system is modeled in only two dimensions rather than three (but all equations apply for each dimension)"
#
# (Slight error: it's not really an $n$-body system, there's only three bodies, and one of them is fixed in space.)
#
# To keep this short, I'm not going to paste in all of the other changes I made in explicitly adding these definitions, but you see what I mean.

# %% [markdown]
# > You talk about "win condition" but then don't state what it is
#
# I introduced this at the line "Ship Destruction and Win Condition," and the problem with this section is that the "win condition" is really referring to a more general discussion of the potential ways in which this simulation could turn out negatively for the astronauts (i.e., being destroyed by from a collision with the planet or sucked into the gravitational pull of the black hole). I'll remedy this by changing the title from "Ship Destruction and Win Condition" to just "Ship Destruction."

# %% [markdown]
# > Optimization: I got lost in the third paragraph. Slow down a bit and explain things a bit more clearly

# %% [markdown]
# I think the reason why this is so terribly unclear is because I jumped so quickly into discussing the exact details for how the optimization works rather than spending a bit of time to discuss the overall simulation as a bigger picture. To simplify that, I'm going to split the optimization section into two parts: a broader discussion of how the optimization process works (and how it fits into the overall simulation) and the present deep-dive into how optimization works.
#
# This is a bit too long to add here, but you can find this addition under the "Optimization" section, with the title "A Broader Understanding of the Optimization."

# %% [markdown]
# > This equation is a bit weird: $w_2 - w_3 > w_3 - w_1$. It can also be written as $w_1 + w_2 - 2 w_3 > 0$. What does that really mean?

# %% [markdown]
# I see what you mean. I think this is best explained with words rather than with equations then. It should really be understood in exactly the way that its written out: the distance bias $w_2$ should be more important than the speed bias $w_3$ but the bias for speed should also be more important than the bias for fuel $w_1$. I completely see now why it's so confusing (and to be honest, I probably wrote it when I was really tired). Literally all this is intended to convey is $w_2 > w_3 > w_1$.
#
# I'm going to fix this (obviously), but this is a really good time to go back to this section ("Determining the Weights") and really clean it up for clarity's sake. I'm really not happy with how it's written as-is now that I'm seeing it with a nice, fresh pair of eyes. Thank you for pointing it out, Joss.
#
# I'm altering it from (careful, this is long)
#
# > To determine the weights $w_1, w_2, w_3$, I started by understanding that I wanted the radial distance to be, by far, the most important variable in the system, followed by the speed and then the fuel. As well, mathematically, each of the weights should be normalized so that $w_1 + w_2 + w_3 = 1$ for simplicity, and I want the bias for distance, $w_2$, to be much more important than the bias for speed $w_3$ and the bias for fuel $w_1$, so $w_2 - w_3 > w_3 - w_1$.
# >
# > Most importantly, I want these variables to be more or less comparable regardless, so the ratio between each of the weights shouldn't be very high or very low such that one weight is dominating compared to another, and I believe that this works because I'm considering the realistic scenario of people on a space ship: they likely have a set mission to achieve, so running out of fuel would likely be the worst for them in the long term, but in the short term, merely escaping is the most important. From there, the best way to determine whether or not they've escaped is how far they are, and the best way to determine whether or not they will escape (if they haven't already) is how fast they are going. I don't make a consideration of whether the final velocity is oriented correctly (i.e., away from the black hole) as this can be reasonably assumed based on the parameters of the system (i.e., the ship is extremely unlikely to end up oriented in the direction of the black hole due to the restrictions of possible turning angles being explored in the simulation and the magnitude of initival velocities being performed being high enough that the gravitational acceleration from the black hole cannot reverse the motion of the ship during the simulation, so while it is possible that the ship could reverse, it is unlikely to occur during the time range of the simulation).
#
# to
#
# "Let the weights (or biases) be $w_1, w_2,$ and $w_3$ corresponding to remaining fuel, radial distance, and speed respectively. These three final variables are not realistically of equal importance, so these weights shouldn't be equal. For this simulation, we assume that they rank in importance in the following order (from most important to least important:
# 1. Radial Distance
# 2. Final Speed
# 3. Remaining Fuel
#
# This order is picked solely based on intuition. We consider the radial distance to be the most important because the immediate goal of these astronauts is to avoid the black hole at all costs (and nearly all of their efforts through the simulation is to avoid being sucked into the black hole). This is also why the final speed comes in second in importance, as faster exit speeds are more likely to escape the event horizon of the black hole. Then, the remaining fuel on board is considered last as it's important that they maintain some fuel for whatever endeavors they may need fuel for later, but it's not absolutely critical to their survival now.
#
# Therefore, our first criteria for the weights to satisfy is $w_2 > w_3 > w_1$. Next, we want there to be a hierarchical order, but we don't want any particular weight to be too dominant, i.e., the differences in the weights shouldn't be relatively large compared to the weights themselves. The last criteria is that these weights should sum to $1$ (for the sake of clearly expressing that they are weighting values for producing a utility. It doesn't effect the results for the weights to sum to one, but it helps with being clear about their relationship.) With these together, we can more or less pick any set of weights that seems reasonable and satisfies these two qualities, so I went with $w_1=2/10, w_2=5/10,$ and $w_3=3/10$."

# %% [markdown]
# > When you scale down from km to m, why does density not also need to be scaled?

# %% [markdown]
# This is a complete mishap on my part for not explaining it! Argh! The reason is, in short, to make the simulation more interesting. It essentially boils down to the problem that because all of the units are scaled down somewhat willy-nilly, the size ratio between the space ship and the slime planet is completely wrong. Because the slime planet is so small now, without an extremely stiff density (completely unrealistically stiff, less of slime and more like eraser rubber, somewhat), the space ship can just completely pass through the slime planet without much problem. Again, this is because the ratio between the size of the slime planet and the space ship changed drastically as the radius of the slime planet was decreased because the space ship is approximated as a point-mass without a radius, so the ratio between the size of the two objects is essentially just the size of the slime planet itself.
#
# To make this extremely clear (because this is a really big point), I'll add the following:
#
# "*Actual:* For this simulation, I'm scaling down all of the units into a micro-scale, so kilometers can reasonably just become meters. Additionally, the density is going to remain the same despite the scale being reduced as the space ship is a point-mass, so there is no equivalent downscaling in the size of the space ship to compensate for the reduction in the size of the slime planet. This means that it would penetrate the same distance into the slime planet as before without increasing the density, so without making the density quite high, it could completely pass through the planet without much impulse (which would make for a very boring simulation, as the ship would almost never be destroyed)."

# %% [markdown]
# > What do you mean by spherical growth exponenent?

# %% [markdown]
# I'm going to explain this in more detail in addressing your later point "Explain in plain language what the idea is of the Hunt-Crossley nonlinear contact model."

# %% [markdown]
# > Reference: For the slime planet's initial position, I picked roughly one-fourth the orbital distance of Mercury from the Sun (which orbits at roughly $58 \times 10^9$ meters 7)), so $14.5 \times 10^9$. Furthermore, I also picked the orbital speed of Mercury at about 47 km/s 8.
# >
# >I lost the thread here. what's your (0,0) reference point? Is the planet moving straight or orbiting? If it is that slime planet is orbiting the black hole, it does not seem that the numbers you provided are consistent with how fast something would be moving if it was 1/4 the orbital radius as mercury.

# %% [markdown]
# Okay, I'll admit, this was not my proudest work regarding communication, so I'll need to take these questions one at a time.
#
# > What's your (0,0) reference point?
#
# 1. First, the $(0,0)$ reference point is the location of the black hole (and this is maintained in the actual simulation as well). Where I think the confusion lies here is in understanding how I only described the radial distance of the slime planet from the black hole rather than exactly where it is located in 2-D space. I'll be more explicit about this by stating
#
# "Once again, the black hole is situated at (0,0) for the entirety of the simulation. With respect to this origin, the slime planet will be located at the same $y$-value of 0 and at a radial orbiting distance similar to something in our solar system as a reference. In this case, I decided to go with something at roughly one-fourth the distance with which Mercury is orbiting the Sun, or $14.5 \times 10^9$ meters [[7]](https://en.wikipedia.org/wiki/Mercury_(planet))."
#
# > Is the planet moving straight or orbiting? If it is that the slime planet is orbiting the black hole, it does not seem that the numbers your provided are consistent with how fast something would be moving if it was 1/4 the orbital radius as mercury.
#
# 2. You're absolutely right. In any realistic case, this planet is far too close for an orbit. In this simulation, this planet is essentially making a straight motion, as I've made the mass of the black hole so little that it essentially doesn't effect the slime planet. I'm not extremely familiar with what these numbers would look like in the realistic case, but this has no real bearing on the rest of the simulation, so I'll just be explicit that this is an entirely unrealistic limitation of the simulation by adding
#
# "For this simulation, the planet is assumed to be not orbiting the black hole, and the orbital/gravitational relationship with the black hole and the slime planet does not need to be stable in any way whatsoever (as it makes no difference to the astronauts), so I'll just arbitrarily pick a speed of the planet as the orbital speed of Mercury of about 47 km/s [[8]](https://science.nasa.gov/mercury/facts)."

# %% [markdown]
# > In-line citations. Your formatting of just including a number ("9") vs doing it as a bracketed number ("[9]") or superscripted ("⁹") makes it very hard to tell this it is a citation

# %% [markdown]
# This is an easy fix. I just went through and manually wrote in the brackets on each citation.

# %% [markdown]
# > I feel like you did a great job of interweaving your markdown and code blocks when defining important values!

# %% [markdown]
# Thank you.

# %% [markdown]
# > "$2\times 10^{30}$." Units?

# %% [markdown]
# Good catch. Kilograms.

# %% [markdown]
# > My understanding is that the mass lower limit for a stellar black hole is 2-3 times that of the sun

# %% [markdown]
# And you would be right. It's not necessary that I make this simulation realistic in this way (as it's already so unrealistic in other values), so I'll just keep it at the mass that it's at and be explicit about this: "This black hole is ideally a solar-mass black hole, which would give it a mass of at least $6\times 10^{30}$ kilograms (at the minimum, about 3 times the mass of the sun). However, for this simulation, we'll just assume the black hole is the same mass as the sun for simplicity."

# %% [markdown]
# > Explain in plain language what the idea is of the Hunt-Crossley nonlinear contact model

# %% [markdown]
# Okay, this is actually a big one. Going back and rereading my treatment of the Hunt-Crossley model with fresh eyes has shown me just how little I really explained or justified this equation, as it is absolutely core to how the mechanics of this simulation works.
#
# For one, I didn't really explain what the equation is actually doing (and why it's formulated in the way that it is), what each of the variables mean in relation to the real world, and so on. I also didn't event explain why I chose the Hunt-Crossley model over the multitudes of other models that exist (why I'm doing a softbody collision rather than a rigidbody collision, why I chose a nonlinear model over a linear model, etc.).
#
# To fix this, I've overhauled the "Elastic Jello Collision" section with a section titled "Understanding the Hunt-Crossley Model" to explain all of this in detail. It's a bit long, so I won't be including it in this document.

# %% [markdown]
# > For testing the system with one-simulation, a trajectory plot would be really helpful
# >
# > Fig 3: What is it that the reader should have learned from this? Given that energy and momentum shouldn't be conserved (as you have pointed out), what insight does the reader get into the system? This seems more like a validation that would make sense in the appendix.
#
# I'd actually like to combine these two points of yours. I think you make a good point that Figure 3 doesn't really add anything of value (and I can't really think of any way to extend it to provide anything interesting), but a trajectory plot would definitely provide some useful information for the reader. Therefore, I'm going to switch Figure 3 to be a trajectory plot and comment on that instead!

# %% [markdown]
# > Fig 5: Revise the axis to be in degrees (you don't need to re-run anything, just recale the axis)

# %% [markdown]
# This was a really simple change. All I needed was `np.rad2deg` and to change the units.

# %% [markdown]
# > Fig 5: what is utility? You should define it clearly here and specify what object the speed and angle are referring to. This caption is missing the 1-2 sentences of context before getting into the interpretation

# %% [markdown]
# Right. I'll restate the meaning of the speed, angle, and utility at the start with an introductory phrase like "This full phase contour is over an angular domain of a 90 (hard left) to -90 (hard right) degree turn between initial velocities of 1 to 30 m/s. As stated before, the simulation has produced a mapping of each phase coordinate $(\theta,v_0)$ to a scalar utility (or "success" or "optimization") score $U$, with higher utility scores being more favorable simulations based on the model weights, and for this model, the weights are $w_{fuel}=\frac{2}{10},w_{distance}=\frac{5}{10},$ and $w_{speed}=\frac{3}{10}$."
#
# Although, rather than adding it to the caption, I decided to add it before the figure underneath the code snippet as it would make the caption very long, and this serves a dual-purpose of explaining what the contour generation code is doing very well.

# %% [markdown]
# > Optimal pairing: This should be a subsection and have the important context re-introduced. I struggled to follow the overall narrative of this section and the printed outputs lack units and information about what quantities they are referring to. This section would also benefit from a trajectory plot

# %% [markdown]
# Right. First, I made sure to add a subsection header to distinguish this, and I'll add the following context to begin:
#
# "Now, we've reached the "optimal" phase coordinate for this simulation, and this pair $(\theta,v_0)$ represents the turning angle and initial velocity that maximizes the chance of long-term survival for the astronauts on board this ship under the assumptions/opinions of our optimization model. Taking a closer look into what occurs at this coordinate will yield some valuable insight into this simulation, because, for example, if this is a very trivial or otherwise poor result (like in the case that we cannot explain its behavior), then our optimization assumptions need to be reworked as the model is not optimizing for a true best-case scenario."
#
# Then, I added some dedicated code to write the units and describe what is being printed:
# ```python
# print(f'Optimal Angle = {np.rad2deg(results.optimal_pair[0]):.1f} deg.')
# print(f'Optimal Starting Velocity = {results.optimal_pair[1]:.1f} m/s')
# ```
#
# And from there, I also added a markdown cell to outright say what it is:
#
# "In this case, the model obtained an ideal coordinate of $\theta=30\text{ deg}$ and $v_0=30 \text{ m/s}$."
#
# Lastly, I added a trajectory plot like you suggested.

# %% [markdown]
# > Given your optimization approach, it would be good to show how the results would vary for 1-2 other sets of weights. "If we emphasized x more, we would find...."

# %% [markdown]
# I really loved this idea. I went a bit overboard, and did it for much more than 1-2 other sets of weights. Rather, I used this as more of a miniature exploration into the phase space of the weights themselves, and it yielded some very interesting answers. I can't paste it into this document as well (as it's too long), but it is all the way at the bottom of the document under "Weighting Alternatives for the Optimization."
#
# One major error that this exploration made me notice is that I had actually set the amount of fuel on-board far too low, and I needed to increase it from 500 kilograms to 10,000 kilograms.

# %% [markdown]
# > Both types of appendices are extremely well done!
#
# Thanks a ton.

# %% [markdown]
# Again, I hope these work. Let me know if anything is still lacking (if there is still time in the course to do so, and if not, thanks for the great semester!)
#
# As a side note, I've really loved Physics 210, and like I said at the start of the course, I really want to become a Computational Physicist. I think that this class has really made me certain that this is what I want to do.
#
# Thanks a ton,
#
# Mufaro Machaya
